# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import seaborn as sns
import streamlit as st

# %%
df = pd.read_csv('cricket.csv')
df
# Out:
#    ICC ODI CRICKET MEN'S WORLD CUP 2023 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0         POINT TABLE OF WORLD CUP 2023        NaN        NaN        NaN
# 1                                   SNO       TEAM          M          W
# 2                                     1        IND          9          9
# 3                                     2         SA          9          7
# 4                                     3        AUS          9          7
# 5                                     4         NZ          9          5
# 6                                     5        PAK          9          4
# 7                                     6        AFG          9          4
# 8                                     7        ENG          9          3
# 9                                     8        BAN          9          2
# 10                                    9         SL          9          2
# 11                                   10        NED          9          2
#
#    Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0         NaN        NaN        NaN        NaN
# 1           L        NRR        Pts     Last 5
# 2           0       2.57         18      WWWWW
# 3           2      1.261         14      WLWWW
# 4           2      0.841         14      WWWWW
# 5           4      0.743         10      WLLLL
# 6           5     -0.199          8      LWWLL
# 7           5     -0.336          8      LLWWW
# 8           6     -0.572          6      WWLLL
# 9           7     -1.087          4      LWLLL
# 10          7     -1.419          4      LLLLW
# 11          7     -1.825          4      LLLWL
